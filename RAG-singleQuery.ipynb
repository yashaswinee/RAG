# %%
! pip install langchain_community tiktoken langchain-openai langchainhub chromadb langchain sentence-transformers
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain_community in /home/yeshu/.local/lib/python3.10/site-packages (0.3.29)
# Requirement already satisfied: tiktoken in /home/yeshu/.local/lib/python3.10/site-packages (0.11.0)
# Requirement already satisfied: langchain-openai in /home/yeshu/.local/lib/python3.10/site-packages (0.3.32)
# Requirement already satisfied: langchainhub in /home/yeshu/.local/lib/python3.10/site-packages (0.1.21)
# Requirement already satisfied: chromadb in /home/yeshu/.local/lib/python3.10/site-packages (1.0.20)
# Requirement already satisfied: langchain in /home/yeshu/.local/lib/python3.10/site-packages (0.3.27)
# Requirement already satisfied: sentence-transformers in /home/yeshu/.local/lib/python3.10/site-packages (5.1.1)
# Requirement already satisfied: numpy>=1.26.2 in /home/yeshu/.local/lib/python3.10/site-packages (from langchain_community) (1.26.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /home/yeshu/.local/lib/python3.10/site-packages (from langchain_community) (9.0.0)
# Requirement already satisfied: langsmith>=0.1.125 in /home/yeshu/.local/lib/python3.10/site-packages (from langchain_community) (0.4.26)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/yeshu/.local/lib/python3.10/site-packages (from langchain_community) (3.10.10)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/yeshu/.local/lib/python3.10/site-packages (from langchain_community) (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.75 in /home/yeshu/.local/lib/python3.10/site-packages (from langchain_community) (0.3.75)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /home/yeshu/.local/lib/python3.10/site-packages (from langchain_community) (2.10.1)
# Requirement already satisfied: PyYAML>=5.3 in /home/yeshu/.local/lib/python3.10/site-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/yeshu/.local/lib/python3.10/site-packages (from langchain_community) (2.0.28)
# Requirement already satisfied: requests<3,>=2.32.5 in /home/yeshu/.local/lib/python3.10/site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.6.7 in /home/yeshu/.local/lib/python3.10/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: regex>=2022.1.18 in /home/yeshu/.local/lib/python3.10/site-packages (from tiktoken) (2024.9.11)
# Requirement already satisfied: openai<2.0.0,>=1.99.9 in /home/yeshu/.local/lib/python3.10/site-packages (from langchain-openai) (1.106.1)
# Requirement already satisfied: packaging<25,>=23.2 in /home/yeshu/.local/lib/python3.10/site-packages (from langchainhub) (24.2)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in /home/yeshu/.local/lib/python3.10/site-packages (from langchainhub) (2.32.4.20250809)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/yeshu/.local/lib/python3.10/site-packages (from chromadb) (1.22.1)
# Requirement already satisfied: jsonschema>=4.19.0 in /home/yeshu/.local/lib/python3.10/site-packages (from chromadb) (4.21.0)
# Requirement already satisfied: mmh3>=4.0.1 in /home/yeshu/.local/lib/python3.10/site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: overrides>=7.3.1 in /home/yeshu/.local/lib/python3.10/site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: pydantic>=1.9 in /home/yeshu/.local/lib/python3.10/site-packages (from chromadb) (2.11.7)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/yeshu/.local/lib/python3.10/site-packages (from chromadb) (33.1.0)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /home/yeshu/.local/lib/python3.10/site-packages (from chromadb) (0.29.0)
# Requirement already satisfied: orjson>=3.9.12 in /home/yeshu/.local/lib/python3.10/site-packages (from chromadb) (3.10.16)
# Requirement already satisfied: rich>=10.11.0 in /home/yeshu/.local/lib/python3.10/site-packages (from chromadb) (13.9.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/yeshu/.local/lib/python3.10/site-packages (from chromadb) (0.20.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/yeshu/.local/lib/python3.10/site-packages (from chromadb) (1.36.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/yeshu/.local/lib/python3.10/site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: grpcio>=1.58.0 in /home/yeshu/.local/lib/python3.10/site-packages (from chromadb) (1.67.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/yeshu/.local/lib/python3.10/site-packages (from chromadb) (1.36.0)
# Requirement already satisfied: importlib-resources in /home/yeshu/.local/lib/python3.10/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/yeshu/.local/lib/python3.10/site-packages (from chromadb) (1.36.0)
# Requirement already satisfied: typer>=0.9.0 in /home/yeshu/.local/lib/python3.10/site-packages (from chromadb) (0.17.4)
# Requirement already satisfied: build>=1.0.3 in /home/yeshu/.local/lib/python3.10/site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in /home/yeshu/.local/lib/python3.10/site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/yeshu/.local/lib/python3.10/site-packages (from chromadb) (4.12.2)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /home/yeshu/.local/lib/python3.10/site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: httpx>=0.27.0 in /home/yeshu/.local/lib/python3.10/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: tqdm>=4.65.0 in /home/yeshu/.local/lib/python3.10/site-packages (from chromadb) (4.66.5)
# Requirement already satisfied: pypika>=0.48.9 in /home/yeshu/.local/lib/python3.10/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /home/yeshu/.local/lib/python3.10/site-packages (from langchain) (0.3.11)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /home/yeshu/.local/lib/python3.10/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: scikit-learn in /home/yeshu/.local/lib/python3.10/site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in /home/yeshu/.local/lib/python3.10/site-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: Pillow in /home/yeshu/.local/lib/python3.10/site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /home/yeshu/.local/lib/python3.10/site-packages (from sentence-transformers) (0.26.1)
# Requirement already satisfied: torch>=1.11.0 in /home/yeshu/.local/lib/python3.10/site-packages (from sentence-transformers) (2.6.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /home/yeshu/.local/lib/python3.10/site-packages (from sentence-transformers) (4.46.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/yeshu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/yeshu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/yeshu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/yeshu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.5.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/yeshu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/yeshu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.4.3)
# Requirement already satisfied: tomli>=1.1.0 in /home/yeshu/.local/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (2.2.1)
# Requirement already satisfied: pyproject_hooks in /home/yeshu/.local/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/yeshu/.local/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.6.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/yeshu/.local/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx>=0.27.0->chromadb) (2020.6.20)
# Requirement already satisfied: httpcore==1.* in /home/yeshu/.local/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb) (1.0.6)
# Requirement already satisfied: anyio in /home/yeshu/.local/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb) (4.10.0)
# Requirement already satisfied: idna in /home/yeshu/.local/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/yeshu/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/yeshu/.local/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.9.0)
# Requirement already satisfied: filelock in /home/yeshu/.local/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.16.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/yeshu/.local/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (2023.12.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/yeshu/.local/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (0.17.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/yeshu/.local/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (0.32.1)
# Requirement already satisfied: google-auth>=1.0.1 in /home/yeshu/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.40.3)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/yeshu/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: urllib3>=1.24.2 in /home/yeshu/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/yeshu/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/yeshu/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.7.0)
# Requirement already satisfied: requests-oauthlib in /home/yeshu/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: six>=1.9.0 in /home/yeshu/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: durationpy>=0.7 in /home/yeshu/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/yeshu/.local/lib/python3.10/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain_community) (1.33)
# Requirement already satisfied: zstandard>=0.23.0 in /home/yeshu/.local/lib/python3.10/site-packages (from langsmith>=0.1.125->langchain_community) (0.24.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/yeshu/.local/lib/python3.10/site-packages (from langsmith>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: flatbuffers in /home/yeshu/.local/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: coloredlogs in /home/yeshu/.local/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: sympy in /home/yeshu/.local/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: protobuf in /home/yeshu/.local/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (5.28.3)
# Requirement already satisfied: sniffio in /home/yeshu/.local/lib/python3.10/site-packages (from openai<2.0.0,>=1.99.9->langchain-openai) (1.3.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/yeshu/.local/lib/python3.10/site-packages (from openai<2.0.0,>=1.99.9->langchain-openai) (0.6.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=1.99.9->langchain-openai) (1.7.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/yeshu/.local/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.36.0 in /home/yeshu/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.36.0)
# Requirement already satisfied: opentelemetry-proto==1.36.0 in /home/yeshu/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.36.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /home/yeshu/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.65.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.57b0 in /home/yeshu/.local/lib/python3.10/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.57b0)
# Requirement already satisfied: backoff>=1.10.0 in /home/yeshu/.local/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/yeshu/.local/lib/python3.10/site-packages (from pydantic>=1.9->chromadb) (0.4.1)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/yeshu/.local/lib/python3.10/site-packages (from pydantic>=1.9->chromadb) (2.33.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/yeshu/.local/lib/python3.10/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/yeshu/.local/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.0.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/yeshu/.local/lib/python3.10/site-packages (from requests<3,>=2.32.5->langchain_community) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/yeshu/.local/lib/python3.10/site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/yeshu/.local/lib/python3.10/site-packages (from rich>=10.11.0->chromadb) (2.16.1)
# Requirement already satisfied: greenlet!=0.4.17 in /home/yeshu/.local/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.2.3)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/yeshu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/yeshu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/yeshu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/yeshu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/yeshu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.4.5.8)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/yeshu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/yeshu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.6.1.9)
# Requirement already satisfied: triton==3.2.0 in /home/yeshu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: networkx in /home/yeshu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/yeshu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/yeshu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/yeshu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/yeshu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (10.3.5.147)
# Requirement already satisfied: jinja2 in /home/yeshu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/yeshu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/yeshu/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/yeshu/.local/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: safetensors>=0.4.1 in /home/yeshu/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: click>=8.0.0 in /home/yeshu/.local/lib/python3.10/site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /home/yeshu/.local/lib/python3.10/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: watchfiles>=0.13 in /home/yeshu/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in /home/yeshu/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/yeshu/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: httptools>=0.5.0 in /home/yeshu/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: joblib>=1.2.0 in /home/yeshu/.local/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/yeshu/.local/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/yeshu/.local/lib/python3.10/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/yeshu/.local/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/yeshu/.local/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/yeshu/.local/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.2)
# Requirement already satisfied: zipp>=3.20 in /home/yeshu/.local/lib/python3.10/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/yeshu/.local/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<2.0.0,>=0.3.75->langchain_community) (2.4)
# Requirement already satisfied: mdurl~=0.1 in /home/yeshu/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/yeshu/.local/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.6.7->langchain_community) (1.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/yeshu/.local/lib/python3.10/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain_community) (0.2.0)
# Requirement already satisfied: humanfriendly>=9.1 in /home/yeshu/.local/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/yeshu/.local/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/yeshu/.local/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.5.1)

# %%
import getpass
import os

os.environ['LANGCHAIN_TRACING_V2'] = 'True'
os.environ['LANGSMITH_ENDPOINT']= 'https://api.smith.langchain.com'
os.environ['LANGSMITH_API_KEY']=os.environ['LANGSMITH_API_KEY_2']

os.environ['OPENAI_API_KEY'] = os.environ['OPENAI_API_KEY']
os.environ['GEMINI_API_KEY'] = os.environ['GEMINI_API_KEY']

# %%
question = 'Summarise the content given'
with open('smallContent.txt', 'r') as f:
    data = f.read()

# to approximate tokens
import tiktoken

def count_tokens(content, encoding_name='cl100k_base'):
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(content))
    return num_tokens

tokens = count_tokens(question)
print(f"question: {tokens}")

tokens = count_tokens(data)
print(f'content: {tokens}')
# Out:
# question: 6
# content: 787

# %%
# split
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size = 500, chunk_overlap=10)
splits = text_splitter.create_documents([data])
print(splits[1])
# Out:
# page_content='He was too much absorbed with his own thoughts to give any immediate
#      answer to my remonstrance. He leaned upon his hand, with his untasted
#      breakfast before him, and he stared at the slip of paper which he had
#      just drawn from its envelope. Then he took the envelope itself, held
#      it up to the light, and very carefully studied both the exterior and
#      the flap.'

# %%
# embeddings
from langchain_community.embeddings import HuggingFaceEmbeddings

model_name = 'intfloat/e5-large'
embeddings = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs={'device': 'cpu'},  
    encode_kwargs={'normalize_embeddings': True}
)
print(embeddings)
# Out:
# /tmp/ipykernel_55233/3316980068.py:5: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# 2025-11-03 11:08:29.512654: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-03 11:08:29.540632: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-03 11:08:29.540672: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-03 11:08:29.540706: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-03 11:08:29.548809: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-03 11:08:30.418599: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# client=SentenceTransformer(
#   (0): Transformer({'max_seq_length': 512, 'do_lower_case': False, 'architecture': 'BertModel'})
#   (1): Pooling({'word_embedding_dimension': 1024, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# ) model_name='intfloat/e5-large' cache_folder=None model_kwargs={'device': 'cpu'} encode_kwargs={'normalize_embeddings': True} multi_process=False show_progress=False

# %%
# retriever
from langchain_community.vectorstores import Chroma

persist_directory = './chroma_e5_db'

vectorstore = Chroma.from_documents(
    documents=splits,
    embedding=embeddings,  
    persist_directory=persist_directory
)

# %%
# Retrieval and Generation

retriever = vectorstore.as_retriever(kwargs=3)

# 1. Retrieval
from langchain import hub

prompt = hub.pull("rlm/rag-prompt")

# LLM
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    google_api_key=os.environ["GEMINI_API_KEY"],
)

# %%
# post processing - generation
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# Question
rag_chain.invoke("Who is Porlock?")
# Out:
# 'Porlock is a nom-de-plume, not his real name, representing a shifty and evasive personality. He is difficult to trace and has openly stated that his name is not his own. Porlock is important not for himself, but for his connection to a "great man."'
